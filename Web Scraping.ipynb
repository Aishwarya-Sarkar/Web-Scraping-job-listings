# %% [markdown]
# ### Import necessary Packages:

# %%
from selenium import webdriver
import time
import pandas as pd

# %% [markdown]
# ### Setup Web-Driver:

# %%
search_query = 'https://www.indeed.com/q-data-scientist-jobs.html'
driver = webdriver.Chrome(executable_path='C:/Users/Aishwarya/Downloads/chromedriver.exe')

driver.get(search_query)
driver.maximize_window()

time.sleep(5)

# %% [markdown]
# ### Scrape data from the web-page:

# %%
job_details = []
job_info = []

#list of all jobs with their elements
job_list = driver.find_elements_by_xpath("//div[@class='job_seen_beacon']")
for job in job_list:
    
    #job Title
    title = job.find_elements_by_xpath(".//div/h2/span")[0]
    
    #Company Name
    company=job.find_elements_by_xpath(".//div[@class='heading6 company_location tapItem-gutter']//span")[0]
    #rating = job.find_elements_by_xpath(".//span[@class='ratingNumber']/span")[0]
    
    #Job Location
    location= job.find_elements_by_xpath(".//div[@class='companyLocation']")[0]
    
    #Job Posting Date
    posting_date = job.find_elements_by_xpath(".//span[@class='date']")[0]
    
    #Job Summary
    summary = job.find_elements_by_xpath(".//div[@class='job-snippet']")[0]
    
    job_info = [title.text, company.text, location.text, summary.text, posting_date.text]
    job_details.append(job_info)

# %%
next_page_button = driver.find_element_by_class_name('pn')

#click on the button for next page
next_page_button.click()

time.sleep(5)

# %%
#close the popup
close_button= driver.find_elements_by_xpath("//button[@class='popover-x-button-close icl-CloseButton']")[0]
close_button.click()

# %%
#list of all jobs with their elements for the next page
job_list = driver.find_elements_by_xpath("//div[@class='job_seen_beacon']")
for job in job_list:
    
    #job Title
    title = job.find_elements_by_xpath(".//div/h2/span")[0]
    
    #Company Name
    company=job.find_elements_by_xpath(".//div[@class='heading6 company_location tapItem-gutter']//span")[0]
    #rating = job.find_elements_by_xpath(".//span[@class='ratingNumber']/span")[0]
    
    #Job Location
    location= job.find_elements_by_xpath(".//div[@class='companyLocation']")[0]
    
    #Job Posting Date
    posting_date = job.find_elements_by_xpath(".//span[@class='date']")[0]
    
    #Job Summary
    summary = job.find_elements_by_xpath(".//div[@class='job-snippet']")[0]
    
    job_info = [title.text, company.text, location.text, summary.text, posting_date.text]
    job_details.append(job_info)

# %%
#construct the dataframe
df = pd.DataFrame(job_details, columns= ['Job Title', 'Company', 'Location', 'Summary', 'Posting Date'])

#close the driver
driver.quit()

#display the dataframe
job_details_df
# Out:
#                                             Job Title  \
# 0                                      Data Scientist
# 1                             Graduate Data Scientist
# 2                          Entry Level Data Scientist
# 3                               Junior Data Scientist
# 4                                      Data Scientist
# 5                            Data Scientist, Dolby.io
# 6                                      Data Scientist
# 7                            Associate Data Scientist
# 8                                      Data Scientist
# 9                               Senior Data Scientist
# 10                                     Data Scientist
# 11                                     Data Scientist
# 12                                Senior Data Analyst
# 13                          Data Scientist III-Remote
# 14                            [Parade] Data Scientist
# 15                                     Data Scientist
# 16                                     Data Scientist
# 17                                     Data Scientist
# 18                         Data Scientist GS-12/13/14
# 19                                  Data Scientist II
# 20                              Senior Data Scientist
# 21                                     Data Scientist
# 22                                     Data Scientist
# 23  Data Scientist, Product Analytics (Remote - U.S.)
# 24                                     Data Scientist
# 25                                    Data Scientists
# 26                                     Data Scientist
# 27                                     Data Scientist
# 28                                     Data Scientist
# 29                                     Data Scientist
#
#                             Company  \
# 0                        Activision
# 1                              Mars
# 2    Toyota Connected North America
# 3                            Toyota
# 4       Central Intelligence Agency
# 5                             Dolby
# 6                         TurnPoint
# 7                         WALGREENS
# 8                     Doosan Bobcat
# 9                 Soaren Management
# 10  Lake Washington School District
# 11               Warner Music Group
# 12                      Medely Inc.
# 13                       John Deere
# 14                      RocketPower
# 15                          eHealth
# 16                         Pluto TV
# 17         HarperCollins Publishers
# 18  Federal Bureau of Investigation
# 19          Aristocrat Technologies
# 20                         Endeavor
# 21                  Grammarly, Inc.
# 22                       John Deere
# 23                        Atlassian
# 24                           Toyota
# 25                          Brillio
# 26                   comScore, Inc.
# 27                          Zest AI
# 28                          Digitas
# 29                   Charles Schwab
#
#                                              Location  \
# 0                                     Foster City, CA
# 1                                        New York, NY
# 2                                    Plano, TX•Remote
# 3                                     Plano, TX 75023
# 4            Washington, DC 20505 (Foggy Bottom area)
# 5                                   San Francisco, CA
# 6                       Atlanta, GA 30318+2 locations
# 7                   Chicago, IL 60603 (The Loop area)
# 8                     West Fargo, ND 58078+1 location
# 9   Scottsdale, AZ 85254 (Paradise Valley area)•Te...
# 10                                        Redmond, WA
# 11                                       New York, NY
# 12                                      Remote•Remote
# 13                              Cary, NC 27518•Remote
# 14                                      Remote•Remote
# 15                                    Santa Clara, CA
# 16                              Los Angeles, CA 90069
# 17       New York, NY 10007 (Financial District area)
# 18                                Pocatello, ID 83201
# 19                                      Las Vegas, NV
# 20                                       New York, NY
# 21  San Francisco, CA 94104 (Financial District ar...
# 22                                 Johnston, IA 50131
# 23                                       New York, NY
# 24                                    Plano, TX 75023
# 25                                          Tampa, FL
# 26         New York, NY 10001 (Garment District area)
# 27                                        Burbank, CA
# 28                  New York, NY 10104 (Midtown area)
# 29                                         Austin, TX
#
#                                               Summary       Posting Date
# 0   Develop novel analytics to qualitatively deduc...              Today
# 1   Build understanding of the Mars Petcare data e...         4 days ago
# 2   Perform data analysis and derive meaningful in...          1 day ago
# 3   Comprehensive health care and wellness plans f...         7 days ago
# 4   Our benefits support every aspect of a working...       30+ days ago
# 5   With an eye to capture analytics value for the...        20 days ago
# 6   Data scientists have a wide range of technical...        Just posted
# 7   Develops basic tests and validates hypotheses ...         3 days ago
# 8   The PIT Data Scientist is responsible for expl...        Just posted
# 9   We are currently looking for an experienced Se...        Just posted
# 10  Three (3) years of experience developing deliv...        25 days ago
# 11  The Research + Analysis department works to in...        19 days ago
# 12  Ability to analyze data and condense data to t...  Active 4 days ago
# 13  Create and implement algorithms which manage t...          1 day ago
# 14  We’re looking for a data scientist with strong...          1 day ago
# 15  Participate in all aspects of the project life...        28 days ago
# 16  1 to 3 years of commercial experience in a dat...          1 day ago
# 17  Use machine learning, data mining, and statist...       30+ days ago
# 18  Provide scientific, statistical, and technical...        Just posted
# 19  Lead the technical evaluation and recommendati...              Today
# 20  Job Description Endeavor is an equal opportuni...         5 days ago
# 21  Has deep knowledge and command of product usag...       30+ days ago
# 22  Develop, implement, and manage credit scoring ...       30+ days ago
# 23  Play with our seriously large volume of analyt...         6 days ago
# 24  Comprehensive health care and wellness plans f...        18 days ago
# 25  Key Skills > Python, TensorFlow, SQL Good to h...        Just posted
# 26  Expertise at querying and manipulating data in...              Today
# 27  Translate unstructured business problems into ...         3 days ago
# 28  We build inferential and predictive models, in...        27 days ago
# 29  3-5 years’ of experience in a data engineering...        14 days ago

# %% [markdown]
# ### Save the data to Excel:

# %%
df.to_excel('Indeed_DataScientist_Jobs.xlsx', index= False)
